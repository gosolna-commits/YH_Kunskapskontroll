# %%
import numpy as np             
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('housing(in).csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %% [markdown]
# Ocean_proximty contains text information and has to be replaced with numeric columns (Miracle value)

# %%
#print(df.head())
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
#print(df.tail())
df.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# 207 rows has no information in total_bedroms column.

# %%
df[df.isnull().any(axis=1) ]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                47.0       1256.0             NaN
# 341      -122.17     37.75                38.0        992.0             NaN
# 538      -122.28     37.78                29.0       5154.0             NaN
# 563      -122.24     37.75                45.0        891.0             NaN
# 696      -122.10     37.69                41.0        746.0             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                18.0       3620.0             NaN
# 20268    -119.18     34.19                19.0       2393.0             NaN
# 20372    -118.88     34.17                15.0       4260.0             NaN
# 20460    -118.75     34.29                17.0       5512.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
#
# ...

# %%
print(df.isnull().sum())
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# Remove rows with null values.

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
print(df["ocean_proximity"].unique())
print("")
value_counts = df["ocean_proximity"].value_counts()
print(value_counts)

plt.figure(figsize=(8, 5))
plt.bar(value_counts.index, value_counts.values, color="skyblue", edgecolor="black")
plt.xlabel("Category")
plt.ylabel("Quantity")
plt.title("Distribution of ocean_proximity")
plt.show()
# Out:
# ['NEAR BAY' '<1H OCEAN' 'INLAND' 'NEAR OCEAN' 'ISLAND']
#
# ocean_proximity
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: count, dtype: int64

# %% [markdown]
# Not much information in category island.
# The distribution is not balanced

# %% [markdown]
# Replacement of ocean_proximity with miracle values.

# %%
pd.get_dummies(df.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0          False   False   False      True       False
# 1          False   False   False      True       False
# 2          False   False   False      True       False
# 3          False   False   False      True       False
# 4          False   False   False      True       False
# ...          ...     ...     ...       ...         ...
# 20635      False    True   False     False       False
# 20636      False    True   False     False       False
# 20637      False    True   False     False       False
# 20638      False    True   False     False       False
# 20639      False    True   False     False       False
#
# [20433 rows x 5 columns]

# %%
df=df.join(pd.get_dummies(df.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  <1H OCEAN  \
# 0       322.0       126.0         8.3252            452600.0      False
# 1      2401.0      1138.0         8.3014            358500.0      False
# 2       496.0       177.0         7.2574            352100.0      False
# 3       558.0       219.0         5.6431            341300.0      False
# 4       565.0       259.0         3.8462            342200.0      False
#
#    INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0   False   False      True       False
# ...

# %%
# Histogram – median house value
plt.figure(figsize=(8, 6))
plt.hist(df["median_house_value"], bins=50)
plt.xlabel("Median house value")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Most of the data best represents houses with value between 100000 and 200000. Information concerning expensive houses is not relevant.

# %%
print((df.describe))
#df.describe()
#df
# Out:
# <bound method NDFrame.describe of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
plt.scatter(df['median_income'], df['median_house_value'], alpha=0.7, edgecolor='k')
plt.title('Median House Value vs Median Income', fontsize=14)
plt.xlabel('Median Income', fontsize=12)
plt.ylabel('Median House Value', fontsize=12)
plt.grid(True, alpha=0.6)

# %% [markdown]
# House values over 500000 is not relevant and useable.
# The plot diagram shows a linear correlation between income and house value.

# %%
df.sort_values(['median_house_value'], ascending=[False])
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3571     -118.51     34.25                24.0       4338.0           558.0
# 3533     -118.54     34.26                23.0       4960.0           592.0
# 3486     -118.54     34.28                10.0       7665.0           999.0
# 8637     -118.41     33.88                40.0        925.0           254.0
# 8636     -118.41     33.88                43.0       2492.0           449.0
# ...          ...       ...                 ...          ...             ...
# 5887     -118.33     34.15                39.0        493.0           168.0
# 9188     -117.86     34.24                52.0        803.0           267.0
# 19802    -123.17     40.31                36.0         98.0            28.0
# 2799     -117.02     36.40                19.0        619.0           239.0
# 2521     -122.74     39.71                16.0        255.0            73.0
#
# ...

# %% [markdown]
# Correlation between house value and geographical location.

# %%
import matplotlib.image as mpimg
california_img=mpimg.imread('california.png')
ax = df.plot(kind="scatter", x="longitude", y="latitude", figsize=(10,7),
                  s=df['population']/100, label="Population",
                  c="median_house_value", cmap=plt.get_cmap("jet"),
                  colorbar=False, alpha=0.4)
plt.imshow(california_img, extent=[-124.55, -113.80, 32.45, 42.05], alpha=0.5,
           cmap=plt.get_cmap("jet"))
plt.ylabel("Latitude", fontsize=14)
plt.xlabel("Longitude", fontsize=14)

prices = df["median_house_value"]
tick_values = np.linspace(prices.min(), prices.max(), 11)
cbar = plt.colorbar(ticks=tick_values/prices.max())
cbar.ax.set_yticklabels(["$%dk"%(round(v/1000)) for v in tick_values], fontsize=14)
cbar.set_label('Median House Value', fontsize=16)

plt.legend(fontsize=16)

# %%
df.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# Changing distributen of data

# %%
df['total_rooms'] = np.log(df['total_rooms'] + 1)
df['total_bedrooms'] = np.log(df['total_bedrooms'] + 1)
df['population'] = np.log(df['population'] + 1)         
df['households'] = np.log(df['households'] + 1)

# %%
df.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# Korrelationer
df_num = df.select_dtypes(include=[np.number]).copy()
df_num["total_bedrooms"] = df_num["total_bedrooms"].fillna(df_num["total_bedrooms"].median())

corr = df_num.corr()

plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# Some correlations are expected for example population with total_rooms, total_bedrooms,households. In this first step the correlation between median_house_value and location is missing.

# %%
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# Include location with numerical values in the matrice.

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0     6.781058        4.867534
# 1        -122.22     37.86                21.0     8.867850        7.009409
# 2        -122.24     37.85                52.0     7.291656        5.252273
# 3        -122.25     37.85                52.0     7.150701        5.463832
# 4        -122.25     37.85                52.0     7.395108        5.638355
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0     7.418181        5.926926
# 20636    -121.21     39.49                18.0     6.548219        5.017280
# 20637    -121.22     39.43                17.0     7.720905        6.186209
# 20638    -121.32     39.43                18.0     7.528869        6.016157
# 20639    -121.24     39.37                16.0     7.932362        6.424869
#
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# Correlation between house value and geographical location. I expected a more strong correlation between median_house_value and "near the ocean". Maybe there is a good explanation for this fact. I guess the reason is the median value for house values.

# %%
df.sort_values(['median_house_value'], ascending=[False])
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3571     -118.51     34.25                24.0     8.375399        6.326149
# 3533     -118.54     34.26                23.0     8.509363        6.385194
# 3486     -118.54     34.28                10.0     8.944550        6.907755
# 8637     -118.41     33.88                40.0     6.830874        5.541264
# 8636     -118.41     33.88                43.0     7.821242        6.109248
# ...          ...       ...                 ...          ...             ...
# 5887     -118.33     34.15                39.0     6.202536        5.129899
# 9188     -117.86     34.24                52.0     6.689599        5.590987
# 19802    -123.17     40.31                36.0     4.595120        3.367296
# 2799     -117.02     36.40                19.0     6.429719        5.480639
# 2521     -122.74     39.71                16.0     5.545177        4.304065
#
# ...

# %% [markdown]
# Just a small view of correlation. Expensive houses is placed near the ocena.

# %% [markdown]
# Summary
# Housing database contains 20640 records
# 207 of them has parameters without values (null values). These lines have to be removed
# 10 columns and medium_house_value is the target. The rest is input parameters.
# House value over 500000 is not well represented.
# There is a strong correlation between medium_house_value and median_income.
# There is correlation between median_house_value and location, but not as much as I expected.
# There is, as expected, good relation between median_hosue_value and median_income
# Changed column ocean_proximity to numeric values (Boolean).
# Some columns has not much data. For example "Island" These columns has to be handled.
# Most of the data represents expensive houses.

# %% [markdown]
# 1.Har något varit utmanande i kursen/kunskapskontrollerna? Om ja, hur har du hanterat det? Vilka lärdomar tar du med dig till framtida kurser?
#
# Mycket ny information för mig. Har fått lägga mycket tid och energi. Det är ingen uppoffring alls eftersom jag känner mig mycket intresserad och motiverad.
# Den senaste övningen med EDA var nog den mest utmanande eftersom jag är så förutsättningslös kring detta. Vet inte riktigt vilka konsekvenser det har med olika fel och brister i dataunderlaget. Hur som helst är det nog bra med en rivstart inför AI kursen.
#
# 2.Vilket betyg anser du att du ska ha och varför?
#
# Vill gärna ha VG, men eftersom jag inte har full koll på vad jag borde leverera så är det kanske inte självklart. Hur som helst har jag lagt mycket tid och energi för att leverera något som jag tror är bra och relevant.
#
# 3.
# Något du vill lyfta fram till Terese?
# Bra upplägg och en trevlig kurs. Kan tycka att mötena i grupprummen är lite snurriga och ger inte jättemycket.
# Terese, Du är en mycket trevlig och kunnig lärare. Det kommer även att gälla även om jag inte får VG! ;)
